# %% [markdown]
# # Remote sensing training
# ## Plot boundary and yield download
#
# This notebook downloads and processes plot boundary and yield data for training in smallholder yield measurements. The data is downloaded from [Radiant MLHub](https://www.mlhub.earth/#datasets), an open source repository of remote sensing data that hosts data sets useful for economic development.
#
# This code downloads data which includes plot boundaries, crop type, and yields for 234 plots (containing maize or sorghum) in Uganda. The data was collected in the 2017 growing season by [Dalberg Data Insights](https://www.dalberg.com/what-we-do/dalberg-data-insights).
#
# The start of this notebook is based on, and borrows code from, Radiant MLHub's tutorial code for downloading data, which is available [here](https://github.com/radiantearth/mlhub-tutorials/blob/master/notebooks/radiant-mlhub-api-know-how.ipynb).
#
# You will need to register for an API key from Radiant MLHub to execute the notebook. Follow the instructions on their website to do so, and then save it into a text file and load it in the following code block.
#
# ## Data Citation
# Bocquet, C., & Dalberg Data Insights. (2019) "Dalberg Data Insights Uganda Crop Classification", Version 1.0, Radiant MLHub. Accessed July 2, 2020. https://doi.org/10.34911/RDNT.EII04X

# %%
import requests 
import geopandas as gpd 
import pandas as pd
import glob
import folium 
import re 
import os
from urllib.parse import urlparse

# %%
if len(os.listdir('uganda-crops/raw')) < 27:

    # Load your API key (you should change this)
    ACCESS_TOKEN = open("/home/grady/.ssh/radiant-mlhub").readlines()[0].rstrip()

    # Specify headers according to Radiant MLHub tutorial 
    headers = {
        'Authorization': f'Bearer {ACCESS_TOKEN}',
        'Accept':'application/json'
    }

    # Specify the collection ID of the Uganda crops data set 
    collectionId = 'ref_african_crops_uganda_01'

    # Pull the items and their metadata in the collection
    r = requests.get(f'https://api.radiant.earth/mlhub/v1/collections/{collectionId}/items', 
                     params={'limit':100, 'bbox':[],'datetime':[]}, headers=headers)
    print(r.text)
    collection = r.json()

    # Insert functions to download the items from the Radiant MLHub tutorial (modified to save to a certain directory)
    def get_download_url(item, asset_key, headers):
        asset = item.get('assets', {}).get(asset_key, None)
        if asset is None:
            print(f'Asset "{asset_key}" does not exist in this item')
            return None
        r = requests.get(asset.get('href'), headers=headers, allow_redirects=False)
        return r.headers.get('Location')


    def download_file(url):
        filename = urlparse(url).path.split('/')[-1]
        filepath = 'uganda-crops/raw/' + filename
        r = requests.get(url)
        f = open(filepath, 'wb')
        for chunk in r.iter_content(chunk_size=512 * 1024): 
            if chunk:
                f.write(chunk)
        f.close()
        print(f'Downloaded {filename}')
        return


    # Now iterate through each item in the collection, and download the GeoJSON with plot boundaries and productivity
    for feature in collection.get('features', []):   
        download_file(get_download_url(feature, 'labels', headers))

else:
    print('Boundary data already downloaded.')
# Out:
# {
#     "context": {
#         "limit": 100,
#         "matched": 27,
#         "page": 1,
#         "returned": 27
#     },
#     "features": [
#         {
#             "assets": {
#                 "documentation": {
#                     "href": "https://api.radiant.earth/mlhub/v1/download/03187e1de37500e7d37b3e7b676c02ec7d20bcac9bf0ea0f5b23543f3c9c8b9c",
#                     "title": "Dataset Documentation",
#                     "type": "application/pdf"
#                 },
#                 "labels": {
#                     "href": "https://api.radiant.earth/mlhub/v1/download/32d19e2a00bfcea9d99a3bbd4025ffcd5525d1ec8092c91a5e11d10c4d6f02d1",
#                     "title": "Crop Labels",
#                     "type": "image/tiff"
#                 },
#                 "property_descriptions": {
#                     "href": "https://api.radiant.earth/mlhub/v1/download/2209869bd5c0caa01b8f9a1e20639fd3cb8eb590555e6e1ad7ba76aa936fce47",
#                     "title": "Label Property Descriptions",
#                     "type": "text/csv"
#                 }
#             },
#             "bbox": [
#                 34.1249266666666,
#                 3.64636,
#                 34.31226,
#                 3.7269467
#             ],
#             "collection": "ref_african_crops_uganda_01",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             34.31226,
#                             3.64636
#                         ],
#                         [
#                             34.31226,
#                             3.7269467
#                         ],
#                         [
#                             34.1249266666666,
#                             3.7269467
#                         ],
#                         [
#                             34.1249266666666,
#                             3.64636
#                         ],
#                         [
#                             34.31226,
#                             3.64636
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "ref_african_crops_uganda_01_tile_010_label",
#             "links": [
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_uganda_01/items/ref_african_crops_uganda_01_tile_010_label",
#                     "rel": "self"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_10_12_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_10_17_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_10_22_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_10_27_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_10_2_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_10_7_1",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_11_11_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_11_16_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_11_1_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_11_21_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_11_26_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_11_6_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_12_11_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_12_16_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_12_1_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_12_21_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_12_26_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_12_31_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_12_6_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_1_10_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_1_15_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_1_20_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_1_25_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_1_30_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_1_5_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_2_14_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_2_19_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_2_24_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_2_4_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_2_9_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_3_11_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_3_16_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_3_1_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_3_21_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_3_26_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_3_31_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_3_6_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_4_10_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_4_15_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_4_20_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_4_25_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_4_30_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_4_5_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_5_10_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_5_15_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_5_20_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_5_25_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_5_30_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_5_5_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_6_14_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_6_19_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_6_24_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_6_29_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_6_4_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_6_9_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_7_14_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_7_19_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_7_24_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_7_29_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_7_4_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_7_9_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_8_13_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_8_18_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_8_23_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_8_28_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_8_3_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_8_8_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_9_12_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_9_22_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_9_27_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_9_2_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_9_7_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_uganda_01",
#                     "rel": "parent"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_uganda_01",
#                     "rel": "collection"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/",
#                     "rel": "root"
#                 }
#             ],
#             "properties": {
#                 "datetime": "2018-12-31T00:00:00Z",
#                 "label:description": "Uganda Tile 010 Labels",
#                 "label:methods": [
#                     "manual"
#                 ],
#                 "label:properties": null,
#                 "label:tasks": [
#                     "classification"
#                 ],
#                 "label:type": "vector"
#             },
#             "stac_extensions": [
#                 "label"
#             ],
#             "type": "Feature"
#         },
#         {
#             "assets": {
#                 "documentation": {
#                     "href": "https://api.radiant.earth/mlhub/v1/download/149eb6848d018a40480b7babab4b5ff3df0a397153d40fd9bbbe5e0472b745a5",
#                     "title": "Dataset Documentation",
#                     "type": "application/pdf"
#                 },
#                 "labels": {
#                     "href": "https://api.radiant.earth/mlhub/v1/download/ee57d09c4d5629b2b478c0cf0842bd719ff5d4d00ea4af65c41374641a20d1d4",
#                     "title": "Crop Labels",
#                     "type": "image/tiff"
#                 },
#                 "property_descriptions": {
#                     "href": "https://api.radiant.earth/mlhub/v1/download/5e388cb4218baa976d7f9f716c3d43e7267273c529637cd7cf40866e1d3ed73b",
#                     "title": "Label Property Descriptions",
#                     "type": "text/csv"
#                 }
#             },
#             "bbox": [
#                 33.68891,
#                 3.470735,
#                 33.6945567,
#                 3.4746533
#             ],
#             "collection": "ref_african_crops_uganda_01",
#             "geometry": {
#                 "coordinates": [
#                     [
#                         [
#                             33.6945567,
#                             3.470735
#                         ],
#                         [
#                             33.6945567,
#                             3.4746533
#                         ],
#                         [
#                             33.68891,
#                             3.4746533
#                         ],
#                         [
#                             33.68891,
#                             3.470735
#                         ],
#                         [
#                             33.6945567,
#                             3.470735
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "id": "ref_african_crops_uganda_01_tile_016_label",
#             "links": [
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_uganda_01/items/ref_african_crops_uganda_01_tile_016_label",
#                     "rel": "self"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_10_12_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_10_17_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_10_22_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_10_27_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_10_2_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_10_7_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_11_11_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_11_16_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_11_1_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_11_21_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_11_26_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_11_6_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_12_11_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_12_16_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_12_1_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_12_21_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_12_26_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_12_31_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_12_6_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_1_10_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_1_15_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_1_20_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_1_25_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_1_30_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_1_5_1",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_2_14_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_2_19_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_2_24_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_2_4_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_2_9_1",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_3_11_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_3_16_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_3_1_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_3_21_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_3_26_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_3_31_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_3_6_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_4_10_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_4_15_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_4_20_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_4_25_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_4_30_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_4_5_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_5_10_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_5_15_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_5_20_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_5_25_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_5_30_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_5_5_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_6_14_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_6_19_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_6_24_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_6_29_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_6_4_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_6_9_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_7_14_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_7_19_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_7_24_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_7_29_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_7_4_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_7_9_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_8_13_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_8_18_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_8_23_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_8_28_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_8_3_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_8_8_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_9_12_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_9_22_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_9_27_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_9_2_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_WJ_2018_9_7_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_uganda_01",
#                     "rel": "parent"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_uganda_01",
#                     "rel": "collection"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/",
#                     "rel": "root"
#                 }
#             ],
#             "properties": {
#                 "datetime": "2018-12-31T00:00:00Z",
#                 "label:description": "Uganda Tile 016 Labels",
#                 "label:methods": [
#                     "manual"
#                 ],
#                 "label:properties": null,
#                 "label:tasks": [
#                     "classification"
#                 ],
#                 "label:type": "vector"
#             },
#             "stac_extensions": [
#                 "label"
#             ],
#             "type": "Feature"
#         },
#         {
#             "assets": {
#                 "documentation": {
#                     "href": "https://api.radiant.earth/mlhub/v1/download/7eef9607daa366ae03855cfbbaf74f014e0e47e3c274bf6287c268e1b38496aa",
#                     "title": "Dataset Documentation",
#                     "type": "application/pdf"
#                 },
#                 "labels": {
#                     "href": "https://api.radiant.earth/mlhub/v1/download/3218014c71f53e4f699e519302e2c33172d448cf849e25fc79db73e435fd3d80",
#                     "title": "Crop Labels",
# ...
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_4_10_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_4_15_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_4_20_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_4_25_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_4_30_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_4_5_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_5_10_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_5_15_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_5_20_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_5_25_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_5_30_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_5_5_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_6_14_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_6_19_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_6_24_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_6_29_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_6_4_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_6_9_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_7_14_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_7_19_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_7_24_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_7_4_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_7_9_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_8_13_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_8_18_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_8_23_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_8_28_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_8_3_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_8_8_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_9_12_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_9_22_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_9_27_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_9_2_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XJ_2018_9_7_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_11_11_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_11_16_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_11_21_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_11_26_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_11_6_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_12_11_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_12_16_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_12_1_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_12_21_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_12_26_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_12_31_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_12_6_0",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_imagery_01/items/ref_african_crops_imagery_01_36_N_XK_2018_7_29_1",
#                     "rel": "source",
#                     "type": "application/json"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_uganda_01",
#                     "rel": "parent"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_uganda_01",
#                     "rel": "collection"
#                 },
#                 {
#                     "href": "https://api.radiant.earth/mlhub/v1/",
#                     "rel": "root"
#                 }
#             ],
#             "properties": {
#                 "datetime": "2018-12-31T00:00:00Z",
#                 "label:description": "Uganda Tile 015 Labels",
#                 "label:methods": [
#                     "manual"
#                 ],
#                 "label:properties": null,
#                 "label:tasks": [
#                     "classification"
#                 ],
#                 "label:type": "vector"
#             },
#             "stac_extensions": [
#                 "label"
#             ],
#             "type": "Feature"
#         }
#     ],
#     "links": [],
#     "numberMatched": 27,
#     "numberReturned": 27,
#     "stac_extensions": [],
#     "type": "FeatureCollection"
# }
# Downloaded ref_african_crops_uganda_01_tile_010.geojson
# Downloaded ref_african_crops_uganda_01_tile_016.geojson
# Downloaded ref_african_crops_uganda_01_tile_004.geojson
# Downloaded ref_african_crops_uganda_01_tile_007.geojson
# Downloaded ref_african_crops_uganda_01_tile_002.geojson
# Downloaded ref_african_crops_uganda_01_tile_025.geojson
# Downloaded ref_african_crops_uganda_01_tile_026.geojson
# Downloaded ref_african_crops_uganda_01_tile_027.geojson
# Downloaded ref_african_crops_uganda_01_tile_018.geojson
# Downloaded ref_african_crops_uganda_01_tile_019.geojson
# Downloaded ref_african_crops_uganda_01_tile_024.geojson
# Downloaded ref_african_crops_uganda_01_tile_003.geojson
# Downloaded ref_african_crops_uganda_01_tile_005.geojson
# Downloaded ref_african_crops_uganda_01_tile_012.geojson
# Downloaded ref_african_crops_uganda_01_tile_020.geojson
# Downloaded ref_african_crops_uganda_01_tile_008.geojson
# Downloaded ref_african_crops_uganda_01_tile_009.geojson
# Downloaded ref_african_crops_uganda_01_tile_011.geojson
# Downloaded ref_african_crops_uganda_01_tile_006.geojson
# Downloaded ref_african_crops_uganda_01_tile_017.geojson
# Downloaded ref_african_crops_uganda_01_tile_001.geojson
# Downloaded ref_african_crops_uganda_01_tile_022.geojson
# Downloaded ref_african_crops_uganda_01_tile_013.geojson
# Downloaded ref_african_crops_uganda_01_tile_021.geojson
# Downloaded ref_african_crops_uganda_01_tile_023.geojson
# Downloaded ref_african_crops_uganda_01_tile_014.geojson
# Downloaded ref_african_crops_uganda_01_tile_015.geojson

# %% [markdown]
# ## Examine one of the geojson files

# %%
# Load the file in geopandas
gdf = gpd.read_file('uganda-crops/raw/ref_african_crops_uganda_01_tile_010.geojson')

# View the first few rows (there are only a few)
pd.options.display.max_columns = 10
print(gdf.head())
print(gdf.columns)

# Add latitude and longitude of plot centroids to the geodataframe 
gdf['lat'] = gdf.geometry.centroid.y
gdf['lon'] = gdf.geometry.centroid.x

# Examine the data in folium
m = folium.Map([gdf['lat'].mean(), gdf['lon'].mean()], zoom_start=12, tiles='Stamen Terrain')
folium.TileLayer(
        tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
        attr = 'Esri',
        name = 'Esri Satellite',
        overlay = False,
        control = True
       ).add_to(m)
folium.GeoJson(gdf, name='Sample plots').add_to(m)
m
# Out:
#                             id District Estimated Harvest Date  \
# 0  ref_african_crops_kenya_030  KAABONG             2017-12-31
# 1  ref_african_crops_kenya_032  KAABONG             2017-12-31
# 2  ref_african_crops_kenya_035  KAABONG             2017-12-31
# 3  ref_african_crops_kenya_043  KAABONG             2017-12-31
# 4  ref_african_crops_kenya_045  KAABONG             2017-12-31
#
#   Estimated Planting Date Grain_W_g  ...    variety5    variety6    variety7  \
# 0              2017-01-01     452.5  ...    improved    improved    improved
# 1              2017-01-01     140.0  ...  indigenous  indigenous  indigenous
# 2              2017-01-01     212.5  ...  indigenous  indigenous  indigenous
# 3              2017-01-01     436.3  ...        None        None        None
# 4              2017-01-01      62.5  ...        None        None        None
#
#      variety8                                           geometry
# 0    improved  POLYGON ((34.31170 3.64884, 34.31195 3.64923, ...
# 1  indigenous  POLYGON ((34.13610 3.71869, 34.13575 3.71858, ...
# 2  indigenous  POLYGON ((34.31025 3.64706, 34.31049 3.64683, ...
# 3        None  POLYGON ((34.31141 3.64636, 34.31105 3.64650, ...
# 4        None  POLYGON ((34.13032 3.71511, 34.13035 3.71546, ...
#
# [5 rows x 94 columns]
# Index(['id', 'District', 'Estimated Harvest Date', 'Estimated Planting Date',
#        'Grain_W_g', 'HI', 'Moisture', 'Stem_W_g', 'Subcounty', 'Village',
#        'Yield_KgHa', 'crop1', 'crop2', 'crop3', 'crop4', 'crop5', 'crop6',
#        'crop7', 'crop8', 'm_cob1', 'm_cob2', 'm_cob3', 'm_cob4', 'm_cob5',
#        'm_cob6', 'm_cob7', 'm_cob8', 'm_disease1', 'm_disease2', 'm_disease3',
#        'm_disease4', 'm_disease5', 'm_disease6', 'm_disease7', 'm_disease8',
#        'm_plant1', 'm_plant2', 'm_plant3', 'm_plant4', 'm_plant5', 'm_plant6',
#        'm_plant7', 'm_plant8', 'm_worm1', 'm_worm2', 'm_worm3', 'm_worm4',
#        'm_worm5', 'm_worm6', 'm_worm7', 'm_worm8', 'm_worm_nu1', 'm_worm_nu2',
#        'm_worm_nu3', 'm_worm_nu4', 'm_worm_nu5', 'm_worm_nu6', 'm_worm_nu7',
#        'm_worm_nu8', 'quadrant', 's_disease1', 's_disease2', 's_disease3',
#        's_disease4', 's_disease5', 's_disease6', 's_disease7', 's_disease8',
#        's_ear1', 's_ear2', 's_ear3', 's_ear4', 's_ear5', 's_ear6', 's_ear7',
#        's_ear8', 's_plant1', 's_plant2', 's_plant3', 's_plant4', 's_plant5',
#        's_plant6', 's_plant7', 's_plant8', 'surveyorid', 'variety1',
#        'variety2', 'variety3', 'variety4', 'variety5', 'variety6', 'variety7',
#        'variety8', 'geometry'],
#       dtype='object')
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Merge the data
#
# The data is in multiple tiles to begin with. First, combine it into a single geojson. Second, create separate GeoJSON files by crop type.

# %%
files = glob.glob('uganda-crops/raw/*.geojson')
all_plots = pd.concat([
    gpd.read_file(x)
    for x in files
]).pipe(gpd.GeoDataFrame)

all_plots.to_file("uganda-crops/merged/all_plots.geojson", driver='GeoJSON')

# Extract maize plots 
maize = all_plots[all_plots['crop1'] == 'maize']
maize.to_file("uganda-crops/merged/maize.geojson", driver='GeoJSON')

# Extrac sorghum plots 
sorghum = all_plots[all_plots['crop1'] == 'sorghum']
sorghum.to_file("uganda-crops/merged/sorghum.geojson", driver='GeoJSON')

print("There are {} plots, {} maize plots, and {} sorghum plots.".format(len(all_plots), len(maize), len(sorghum)))

# Examine the average area of the plots 
all_plots.crs = 'epsg:4326'
all_plots_aea = all_plots.to_crs('ESRI:102022')
all_plots_aea['area'] = all_plots_aea.geometry.area
all_plots_aea['hectares'] = 0.0001*all_plots_aea['area']
print("The median plot size is {} hectares.".format(all_plots_aea['hectares'].median()))
# Out:
# There are 234 plots, 108 maize plots, and 126 sorghum plots.
# The median plot size is 0.16479175889911296 hectares.

# %% [markdown]
# ## Inspect the merged data

# %% [markdown]
# Before analyzing the data, it may be useful to visualize it to make sure that everything looks correct. The documentation for the data specifies that it was collected in September, 2017. We will search for Sentinel-2 data near that timeframe.
#
# We will search for imagery with less than 10% cloud coverage using the sentinelsat Python package for accessing the API. This can be installed with `pip install sentinelsat`. Credentials for the [Copernicus Open Access Hub](https://scihub.copernicus.eu/) are required. You can either insert your username and password directly into the code, or add the following to a file titled .netrc in your home directory
# ```
# machine scihub.copernicus.eu
# login <your username>
# password <your password>
# ```
# then insert `None` for the username and password in the code.

# %% [markdown]
# ### Prepare AOI

# %% [markdown]
# Before downloading the data, we need to extract an AOI to pass to the API. We will take a convex hull of the full plot boundary data for simplicity.

# %%
aoi = gpd.GeoSeries([all_plots.geometry.unary_union.convex_hull]) 
aoi.to_file("uganda-crops/merged/convex_hull.geojson", driver='GeoJSON')

# %% [markdown]
# ### Filter Sentinel-2 data

# %%
from sentinelsat import SentinelAPI, read_geojson, geojson_to_wkt

# Connect to the API and filter products
sentinel_api = SentinelAPI(None, None, 'https://scihub.copernicus.eu/dhus')
footprint = geojson_to_wkt(read_geojson('uganda-crops/merged/convex_hull.geojson'))
products = sentinel_api.query(footprint, date=('20170815', '20171015'), 
                     platformname='Sentinel-2', cloudcoverpercentage=(0, 10))

# Load the matching products and their footprints into a GeoDataFrame
products_gdf = sentinel_api.to_geodataframe(products)
print('There are {} matching products'.format(len(products_gdf)))
# Out:
# There are 54 matching products
# /home/grady/anaconda3/envs/gpd/lib/python3.7/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %% [markdown]
# ### Examine the filtered data

# %%
import branca
from folium.features import GeoJson, GeoJsonTooltip, GeoJsonPopup


# Dissolve multiple tiles from a single day into one object 
products_gdf['date'] = products_gdf['ingestiondate'].dt.date  # Get date (excluding time)
by_date = products_gdf.dissolve(by='date')  # Dissolve footprints by date

# Calculate the percent coverage of the imagery for each date
all_plots.crs = 'epsg:4326'
def calculate_overlap(row):
    temp = gpd.GeoDataFrame({'geometry': [row.geometry]})
    temp.crs = all_plots.crs
    overlap = gpd.overlay(all_plots, temp, how='intersection')
    return(overlap.unary_union.area/all_plots.unary_union.area)
by_date['coverage'] = by_date.apply(calculate_overlap, axis=1)

# Drop dates with 40% coverage or lower 
by_date = by_date[by_date['coverage'] > 0.4]
print(by_date[['coverage']])

# Remove dates with less than 40% coverage from the orgiginal products 
dates_to_keep = list(by_date.index.values)
products_gdf = products_gdf[products_gdf['date'].isin(dates_to_keep)]
print("There are {} products after coverage filtering.".format(len(products_gdf)))


# Plot the merged footprints for each date that was kept 
footprint = by_date[['geometry', 'coverage']].reset_index()
footprint['date'] = footprint['date'].astype(str)
footprint.crs = 'epsg:4326'

colormap = branca.colormap.LinearColormap(
    vmin=footprint['coverage'].quantile(0.0), 
    vmax=footprint['coverage'].quantile(1), 
    colors=['red','orange','lightblue','green','darkgreen'],
    caption="Coverage",
)

popup = GeoJsonPopup(
    fields=['date', 'coverage'],
    aliases=['Date', 'Coverage'],
    labels=True,
    style="background-color: yellow;",
)

tooltip = GeoJsonTooltip(
    fields=["date", "coverage"],
    aliases=["Date:", "Coverage:"],
    sticky=False,
    labels=True,
    max_width=800,
)


m = folium.Map([footprint.iloc[0].geometry.centroid.y, by_date.iloc[0].geometry.centroid.x], 
               zoom_start=8)

folium.GeoJson(
    footprint,
    style_function=lambda x: {
        "fillColor": colormap(x["properties"]["coverage"])
        if x["properties"]["coverage"] is not None
        else "transparent",
        "color": "black",
        "fillOpacity": 0.4,
    },
    tooltip=tooltip,
    popup=popup
).add_to(m)

folium.GeoJson(all_plots, name='Plots').add_to(m)
m
# Out:
#             coverage
# date
# 2017-08-18  0.406648
# 2017-08-21  0.643209
# 2017-08-23  0.543555
# 2017-09-01  0.637730
# 2017-09-07  0.581251
# 2017-09-09  0.652479
# 2017-09-12  0.549705
# 2017-09-27  0.598909
# 2017-10-02  0.570424
# 2017-10-04  0.652479
# 2017-10-07  0.435734
# There are 47 products after coverage filtering.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Imagery from a single day does not span the full set of plots, but imagery from multiple days does cover the full area. That's because the study region spans 2 swaths, the 290 km wide lines along which the Sentinel-2 satellites collect data. This can be seen by the diagonal lines through the middle of the plots. One can also download Sentinel-2 data acquisition KML files and plot them in GIS software or Google Earth Pro along with the plot boundary data.
#
# Since no single date has imagery for the full sample, we will need to download imagery from multiple dates to create a composite image covering the full sample. Since all of this data will be useful for later analysis, we will download all of the images (with less than 10% cloud cover) from the dates in the `by_date` GeoDataFrame.
#
# L2A imagery is not available for download from 2017 (see the column `producttype`). As a result, we will need to download L1C data, and then process it using Sen2Cor.
#
# L1C imagery older than 12 months is moved to a Long Term Archive. Tiles cannot immediately be downloaded. They first need to be activated, at a rate of 20 per 12 hours, and then become active for download up to 24 hours later. They can be downloaded for up to three days after activation, then they need to be downloaded again. The script below handles this functionality, and in theory it should download all of the imagery if left running for long enough. In practice, the API frequently seemed to fail to activate products even after 24 hours, so much of the Sentinel-2A imagery was downloaded from the USGS Earth Explorer interface. The USGS does not have a mirror of the Sentinel-2B imagery for this time period.

# %% [markdown]
# ## Download Sentinel-2 L1C imagery

# %%
import time
from ratelimit import limits, sleep_and_retry, RateLimitException


pending_ids = []

@sleep_and_retry
@limits(calls=20, period=43200)  # Allow 20 calls per 12 hours 
def activate_product(uid):
    sentinel_api.download(uid, directory_path='imagery/l1c')  # Activate product 
    pending_ids.append(uid)  # Add to list to try download later
    time.sleep(60)  # 1 minute because it failed with rapid requests
    
    
@limits(calls=1, period=3600)  # Try downloads every hour
def try_download():
    for x in pending_ids:
        product_info = sentinel_api.get_product_odata(x)
        if product_info['Online']:
            sentinel_api.download(x, directory_path='imagery/l1c')
            pending_ids.remove(x)
        

# Download all of the products identified earlier 
id_list = products_gdf['uuid'].to_list()
for index, row in products_gdf.iterrows():
    file_path = 'imagery/l1c/' + row['title'] + '.zip'
    if os.path.exists(file_path):
        print('{} already downloaded. Skipping.'.format(row['title']))
        continue
    if len(pending_ids) > 0:  # Download any previously activated products that are now online
        try:
            try_download()
        except RateLimitException:
            pass  # Download attempted within the past hour 
    if row['uuid'] in pending_ids:
        continue  # Because code execution got interrupted 
    product_info = sentinel_api.get_product_odata(row['uuid'])
    if product_info['Online']:
        sentinel_api.download(row['uuid'], directory_path='imagery/l1c')
    else:
        activate_product(row['uuid'])


# Download any activated files that were retrieved but not downloaded 
if len(pending_ids) > 0:
    while len(pending_ids) > 0:
        a = len(pending_ids)
        print('{} Products to download. Checking for online products...'.format(a))
        for x in pending_ids:
            product_info = sentinel_api.get_product_odata(x)
            file_path = 'imagery/l1c/' + product_info['title'] + '.zip'
            if os.path.exists(file_path):
                print('{} already downloaded. Skipping.'.format(product_info['title']))
                pending_ids.remove(x)
                continue
            if product_info['Online']:
                sentinel_api.download(x, directory_path='imagery/l1c')
                pending_ids.remove(x)
        b = a - len(pending_ids)
        print("{} products were downloaded.".format(b))
        time.sleep(3600)  # Leave one hour between download attempts
# Out:
# S2B_MSIL1C_20171007T075949_N0205_R035_T36NWH_20171007T081821 already downloaded. Skipping.
# S2B_MSIL1C_20171007T075949_N0205_R035_T36NWJ_20171007T081821 already downloaded. Skipping.
# S2B_MSIL1C_20171007T075949_N0205_R035_T36NXH_20171007T081821 already downloaded. Skipping.
# S2B_MSIL1C_20171007T075949_N0205_R035_T36NWK_20171007T081821 already downloaded. Skipping.
# S2B_MSIL1C_20171004T074919_N0205_R135_T36NXG_20171004T080547 already downloaded. Skipping.
# S2B_MSIL1C_20171004T074919_N0205_R135_T36NYG_20171004T080547 already downloaded. Skipping.
# S2B_MSIL1C_20171004T074919_N0205_R135_T36NXJ_20171004T080547 already downloaded. Skipping.
# S2B_MSIL1C_20171004T074919_N0205_R135_T36NXH_20171004T080547 already downloaded. Skipping.
# S2B_MSIL1C_20171004T074919_N0205_R135_T36NYH_20171004T080547 already downloaded. Skipping.
# S2A_MSIL1C_20171002T075741_N0205_R035_T36NWJ_20171002T081741 already downloaded. Skipping.
# S2A_MSIL1C_20171002T075741_N0205_R035_T36NWH_20171002T081741 already downloaded. Skipping.
# S2A_MSIL1C_20171002T075741_N0205_R035_T36NWK_20171002T081741 already downloaded. Skipping.
# S2A_MSIL1C_20171002T075741_N0205_R035_T36NXH_20171002T081741 already downloaded. Skipping.
# S2A_MSIL1C_20171002T075741_N0205_R035_T36NXK_20171002T081741 already downloaded. Skipping.
# S2A_MSIL1C_20171002T075741_N0205_R035_T36NXJ_20171002T081741 already downloaded. Skipping.
# S2B_MSIL1C_20170927T075649_N0205_R035_T36NXH_20170927T081641 already downloaded. Skipping.
# S2B_MSIL1C_20170927T075649_N0205_R035_T36NXJ_20170927T081641 already downloaded. Skipping.
# S2B_MSIL1C_20170927T075649_N0205_R035_T36NWJ_20170927T081641 already downloaded. Skipping.
# S2B_MSIL1C_20170927T075649_N0205_R035_T36NXK_20170927T081641 already downloaded. Skipping.
# S2B_MSIL1C_20170927T075649_N0205_R035_T36NWH_20170927T081641 already downloaded. Skipping.
# S2A_MSIL1C_20170912T075611_N0205_R035_T36NXH_20170912T081104 already downloaded. Skipping.
# S2A_MSIL1C_20170912T075611_N0205_R035_T36NXJ_20170912T081104 already downloaded. Skipping.
# S2A_MSIL1C_20170912T075611_N0205_R035_T36NXK_20170912T081104 already downloaded. Skipping.
# S2A_MSIL1C_20170912T075611_N0205_R035_T36NWK_20170912T081104 already downloaded. Skipping.
# S2A_MSIL1C_20170912T075611_N0205_R035_T36NWJ_20170912T081104 already downloaded. Skipping.
# S2A_MSIL1C_20170909T074941_N0205_R135_T36NYG_20170909T080525 already downloaded. Skipping.
# S2A_MSIL1C_20170909T074941_N0205_R135_T36NYH_20170909T080525 already downloaded. Skipping.
# S2A_MSIL1C_20170909T074941_N0205_R135_T36NXG_20170909T080525 already downloaded. Skipping.
# S2A_MSIL1C_20170909T074941_N0205_R135_T36NXH_20170909T080525 already downloaded. Skipping.
# S2B_MSIL1C_20170907T075559_N0205_R035_T36NXH_20170907T081059 already downloaded. Skipping.
# S2B_MSIL1C_20170907T075559_N0205_R035_T36NXJ_20170907T081059 already downloaded. Skipping.
# S2B_MSIL1C_20170907T075559_N0205_R035_T36NXK_20170907T081059 already downloaded. Skipping.
# S2B_MSIL1C_20170907T075559_N0205_R035_T36NWJ_20170907T081059 already downloaded. Skipping.
# S2B_MSIL1C_20170907T075559_N0205_R035_T36NWH_20170907T081059 already downloaded. Skipping.
# S2B_MSIL1C_20170815T074609_N0205_R135_T36NXH_20170815T080856 already downloaded. Skipping.
# S2B_MSIL1C_20170815T074609_N0205_R135_T36NYH_20170815T080856 already downloaded. Skipping.
# S2A_MSIL1C_20170823T075611_N0205_R035_T36NXJ_20170823T080952 already downloaded. Skipping.
# S2A_MSIL1C_20170823T075611_N0205_R035_T36NXH_20170823T080952 already downloaded. Skipping.
# S2A_MSIL1C_20170823T075611_N0205_R035_T36NXK_20170823T080952 already downloaded. Skipping.
# S2A_MSIL1C_20170823T075611_N0205_R035_T36NWJ_20170823T080952 already downloaded. Skipping.
# S2A_MSIL1C_20170823T075611_N0205_R035_T36NWK_20170823T080952 already downloaded. Skipping.
# S2A_MSIL1C_20170820T074941_N0205_R135_T36NXH_20170820T080528 already downloaded. Skipping.
# S2A_MSIL1C_20170820T074941_N0205_R135_T36NYH_20170820T080528 already downloaded. Skipping.
# S2A_MSIL1C_20170820T074941_N0205_R135_T36NXJ_20170820T080528 already downloaded. Skipping.
# S2A_MSIL1C_20170820T074941_N0205_R135_T36NYG_20170820T080528 already downloaded. Skipping.
# S2B_MSIL1C_20170818T075609_N0205_R035_T36NXH_20170818T081846 already downloaded. Skipping.
# S2B_MSIL1C_20170818T075609_N0205_R035_T36NXJ_20170818T081846 already downloaded. Skipping.

# %% [markdown]
# ## Process L1C imagery

# %% [markdown]
# The downloaded imagery is top-of-atmosphere corrected (L1C). We want to generate surface reflectance (L2A) products. To do so, we will use version 2.8 of the program [Sen2Cor](https://step.esa.int/main/third-party-plugins-2/sen2cor/) which the European Space Agency uses to create L2A products.
#
# Follow the stand-along installation instructions, and add the `sen2cor` home directory to your path so that the program can be called by typing `L2A_Processs` from a command line from any directory. Instructions for this are provided in the `sen2cor` documentation.
#
# Next, create a folder called `SRTM` in your `sen2cor` home directory. Then open the file `2.8/cfg/L2A_GIPP.xml` in a text editor (the path is relative to the `sen2cor` home directory). We will keep the default for most options to reflect the ESA's settings on new imagery. However, we will instruct `sen2cor` to download SRTM elevation data for terrain correction. To make this change, add the following two lines near the top of the file:
#
# ```xml
# <DEM_Directory>SRTM</DEM_Directory>
# <DEM_Reference>http://data_public:GDdci@data.cgiar-csi.org/srtm/tiles/GeoTIFF/</DEM_Reference>
# ```
#
# The `sen2cor` program can occassionally run into bugs depending on the version of `sen2cor` and the Sentinel-2 imagery format (e.g. characteristics of the L1C file structure and data format change over time). For instance, `sen2cor` will sometimes fail the first time, but will run successfully if it is called again on the same tile from the same command line immediately after. To limit some of these issues, a wrapper is defined to handle the `L2A_Process` calls.
#
# This function operates in parallel by default. The `sen2cor` program uses a relatively high amount of ram for each image that is processed (around 4gb). Hence, you may not want to run it in parallel depending on your computer's hardware.

# %% [markdown]
# ### Unzip the products
# Maintain zip files as a backup given the time required to access imagery from the Long Term Archive

# %%
import zipfile 

def unzip_l1c(zip_dir, exp_dir):
    for item in os.listdir(zip_dir): # loop through items in dir
        if item.endswith('.zip'): # check for ".zip" extension
            exp_path = exp_dir + '/' + item
            exp_path = exp_path.replace('.zip','.SAFE')
            if os.path.exists(exp_path): 
                print(exp_path + " already exists")
            else:
                file_name = zip_dir + "/" + item
                zip_ref = zipfile.ZipFile(file_name) # create zipfile object
                zip_ref.extractall(exp_dir) # extract file to dir
                zip_ref.close() # close file
                print(exp_path + " successfully written")
                
unzip_l1c('imagery/l1c', 'imagery/l1c')
# Out:
# imagery/l1c/S2A_MSIL1C_20170820T074941_N0205_R135_T36NXH_20170820T080528.SAFE already exists
# imagery/l1c/S2A_MSIL1C_20170820T074941_N0205_R135_T36NXJ_20170820T080528.SAFE already exists
# imagery/l1c/S2A_MSIL1C_20170820T074941_N0205_R135_T36NXK_20170820T080528.SAFE already exists
# imagery/l1c/S2A_MSIL1C_20170820T074941_N0205_R135_T36NYG_20170820T080528.SAFE already exists
# imagery/l1c/S2A_MSIL1C_20170820T074941_N0205_R135_T36NYH_20170820T080528.SAFE already exists
# imagery/l1c/S2A_MSIL1C_20170823T075611_N0205_R035_T36NXK_20170823T080952.SAFE already exists
# imagery/l1c/S2A_MSIL1C_20170909T074941_N0205_R135_T36NXG_20170909T080525.SAFE already exists
# imagery/l1c/S2A_MSIL1C_20170909T074941_N0205_R135_T36NXH_20170909T080525.SAFE already exists
# imagery/l1c/S2A_MSIL1C_20170909T074941_N0205_R135_T36NYG_20170909T080525.SAFE already exists
# imagery/l1c/S2A_MSIL1C_20170909T074941_N0205_R135_T36NYH_20170909T080525.SAFE already exists
# imagery/l1c/S2A_MSIL1C_20170912T075611_N0205_R035_T36NWJ_20170912T081104.SAFE already exists
# imagery/l1c/S2A_MSIL1C_20170912T075611_N0205_R035_T36NWK_20170912T081104.SAFE already exists
# imagery/l1c/S2A_MSIL1C_20170912T075611_N0205_R035_T36NXJ_20170912T081104.SAFE already exists
# imagery/l1c/S2A_MSIL1C_20170912T075611_N0205_R035_T36NXK_20170912T081104.SAFE already exists
# imagery/l1c/S2A_MSIL1C_20171002T075741_N0205_R035_T36NWH_20171002T081741.SAFE already exists
# imagery/l1c/S2A_MSIL1C_20171002T075741_N0205_R035_T36NWJ_20171002T081741.SAFE already exists
# imagery/l1c/S2B_MSIL1C_20171004T074919_N0205_R135_T36NXH_20171004T080547.SAFE already exists
# imagery/l1c/S2B_MSIL1C_20171004T074919_N0205_R135_T36NXJ_20171004T080547.SAFE already exists
# imagery/l1c/S2B_MSIL1C_20171004T074919_N0205_R135_T36NYG_20171004T080547.SAFE already exists
# imagery/l1c/S2B_MSIL1C_20171004T074919_N0205_R135_T36NYH_20171004T080547.SAFE already exists
# imagery/l1c/S2B_MSIL1C_20171007T075949_N0205_R035_T36NWH_20171007T081821.SAFE already exists
# imagery/l1c/S2B_MSIL1C_20171007T075949_N0205_R035_T36NWJ_20171007T081821.SAFE already exists
# imagery/l1c/S2B_MSIL1C_20171007T075949_N0205_R035_T36NWK_20171007T081821.SAFE already exists
# imagery/l1c/S2B_MSIL1C_20171007T075949_N0205_R035_T36NXH_20171007T081821.SAFE already exists
# imagery/l1c/S2A_MSIL1C_20170823T075611_N0205_R035_T36NWJ_20170823T080952.SAFE already exists
# imagery/l1c/S2A_MSIL1C_20170823T075611_N0205_R035_T36NWK_20170823T080952.SAFE already exists
# imagery/l1c/S2A_MSIL1C_20170823T075611_N0205_R035_T36NXG_20170823T080952.SAFE already exists
# imagery/l1c/S2A_MSIL1C_20170823T075611_N0205_R035_T36NXH_20170823T080952.SAFE already exists
# imagery/l1c/S2A_MSIL1C_20170823T075611_N0205_R035_T36NXJ_20170823T080952.SAFE already exists
# imagery/l1c/S2A_MSIL1C_20170912T075611_N0205_R035_T36NXH_20170912T081104.SAFE already exists
# imagery/l1c/S2A_MSIL1C_20171002T075741_N0205_R035_T36NWK_20171002T081741.SAFE already exists
# imagery/l1c/S2B_MSIL1C_20170927T075649_N0205_R035_T36NWJ_20170927T081641.SAFE successfully written
# imagery/l1c/S2B_MSIL1C_20171004T074919_N0205_R135_T36NXG_20171004T080547.SAFE already exists
# imagery/l1c/S2A_MSIL1C_20171002T075741_N0205_R035_T36NXH_20171002T081741.SAFE already exists
# imagery/l1c/S2A_MSIL1C_20171002T075741_N0205_R035_T36NXJ_20171002T081741.SAFE already exists
# imagery/l1c/S2A_MSIL1C_20171002T075741_N0205_R035_T36NXK_20171002T081741.SAFE already exists
# imagery/l1c/S2B_MSIL1C_20170815T074609_N0205_R135_T36NXH_20170815T080856.SAFE successfully written
# imagery/l1c/S2B_MSIL1C_20170815T074609_N0205_R135_T36NYH_20170815T080856.SAFE successfully written
# imagery/l1c/S2B_MSIL1C_20170818T075609_N0205_R035_T36NXH_20170818T081846.SAFE successfully written
# imagery/l1c/S2B_MSIL1C_20170818T075609_N0205_R035_T36NXJ_20170818T081846.SAFE successfully written
# imagery/l1c/S2B_MSIL1C_20170907T075559_N0205_R035_T36NWH_20170907T081059.SAFE successfully written
# imagery/l1c/S2B_MSIL1C_20170907T075559_N0205_R035_T36NWJ_20170907T081059.SAFE successfully written
# imagery/l1c/S2B_MSIL1C_20170927T075649_N0205_R035_T36NXH_20170927T081641.SAFE successfully written
# imagery/l1c/S2B_MSIL1C_20170927T075649_N0205_R035_T36NXJ_20170927T081641.SAFE successfully written
# imagery/l1c/S2B_MSIL1C_20170927T075649_N0205_R035_T36NXK_20170927T081641.SAFE successfully written
# imagery/l1c/S2B_MSIL1C_20170907T075559_N0205_R035_T36NXH_20170907T081059.SAFE successfully written
# imagery/l1c/S2B_MSIL1C_20170907T075559_N0205_R035_T36NXJ_20170907T081059.SAFE successfully written
# imagery/l1c/S2B_MSIL1C_20170907T075559_N0205_R035_T36NXK_20170907T081059.SAFE successfully written
# imagery/l1c/S2B_MSIL1C_20170927T075649_N0205_R035_T36NWH_20170927T081641.SAFE successfully written

# %% [markdown]
# ### Run sen2cor

# %%
import shutil
import multiprocessing 
import subprocess 
import shlex 

l2a_directory = os.path.join(os.getcwd(), 'imagery/l2a')
fileList = glob.glob("imagery/l1c/S2*MSIL1C*.SAFE")  # List the L1C files 

# Remove any files that were already processed 
for x in list(fileList):  # List command is necessary to remove items from the original 
    date = x[23:31]
    tile = x[51:56]
    if len(glob.glob(l2a_directory + '/*L2A*{}*{}*.SAFE'.format(date, tile))) > 0:
        print('{} already processed'.format(x))
        fileList.remove(x)
    else:
        pass
    
# Generate the L2A_Process commands 
commands = ['L2A_Process "' + file + 
            '" --work_dir {} --output_dir {} --res_database_dir {}'.format(l2a_directory, l2a_directory, l2a_directory) 
            for file in fileList]  

maxCores = max(1, min(len(commands), 6))  # Set cores to 6 or the number of files to process
maxAttempts = 3  # Specify the maximum number of retry attempts per file
def process(command):
    attempt = 1         
            
    #Give each tile maxAttempts possible tries and 2 hours to run
    while attempt < maxAttempts:
        try:
            subprocess.check_call(shlex.split(command), timeout=120*60)
            break
            
        except subprocess.CalledProcessError:
            attempt += 1
                
#Use a multiprocessing pool for parallel processing 
hPool = multiprocessing.Pool(processes=maxCores)

# Run function in parallel
hPool.imap_unordered(
    func=process, iterable=commands)

hPool.close()    # Prevent new jobs from running
hPool.join()    # Wait for workers to complete all jobs
# Out:
# imagery/l1c/S2A_MSIL1C_20170820T074941_N0205_R135_T36NXH_20170820T080528.SAFE already processed
# imagery/l1c/S2A_MSIL1C_20170820T074941_N0205_R135_T36NXJ_20170820T080528.SAFE already processed
# imagery/l1c/S2A_MSIL1C_20170820T074941_N0205_R135_T36NXK_20170820T080528.SAFE already processed
# imagery/l1c/S2A_MSIL1C_20170820T074941_N0205_R135_T36NYG_20170820T080528.SAFE already processed
# imagery/l1c/S2A_MSIL1C_20170820T074941_N0205_R135_T36NYH_20170820T080528.SAFE already processed
# imagery/l1c/S2A_MSIL1C_20170823T075611_N0205_R035_T36NXK_20170823T080952.SAFE already processed
# imagery/l1c/S2A_MSIL1C_20170909T074941_N0205_R135_T36NXG_20170909T080525.SAFE already processed
# imagery/l1c/S2A_MSIL1C_20170909T074941_N0205_R135_T36NXH_20170909T080525.SAFE already processed
# imagery/l1c/S2A_MSIL1C_20170909T074941_N0205_R135_T36NYG_20170909T080525.SAFE already processed
# imagery/l1c/S2A_MSIL1C_20170909T074941_N0205_R135_T36NYH_20170909T080525.SAFE already processed
# imagery/l1c/S2A_MSIL1C_20170912T075611_N0205_R035_T36NWJ_20170912T081104.SAFE already processed
# imagery/l1c/S2A_MSIL1C_20170912T075611_N0205_R035_T36NWK_20170912T081104.SAFE already processed
# imagery/l1c/S2A_MSIL1C_20170912T075611_N0205_R035_T36NXH_20170912T081104.SAFE already processed
# imagery/l1c/S2A_MSIL1C_20170912T075611_N0205_R035_T36NXJ_20170912T081104.SAFE already processed
# imagery/l1c/S2A_MSIL1C_20170912T075611_N0205_R035_T36NXK_20170912T081104.SAFE already processed
# imagery/l1c/S2A_MSIL1C_20171002T075741_N0205_R035_T36NWH_20171002T081741.SAFE already processed
# imagery/l1c/S2A_MSIL1C_20171002T075741_N0205_R035_T36NWJ_20171002T081741.SAFE already processed
# imagery/l1c/S2A_MSIL1C_20171002T075741_N0205_R035_T36NWK_20171002T081741.SAFE already processed
# imagery/l1c/S2B_MSIL1C_20171004T074919_N0205_R135_T36NXH_20171004T080547.SAFE already processed
# imagery/l1c/S2B_MSIL1C_20171004T074919_N0205_R135_T36NXJ_20171004T080547.SAFE already processed
# imagery/l1c/S2B_MSIL1C_20171004T074919_N0205_R135_T36NYG_20171004T080547.SAFE already processed
# imagery/l1c/S2B_MSIL1C_20171004T074919_N0205_R135_T36NYH_20171004T080547.SAFE already processed
# imagery/l1c/S2B_MSIL1C_20171007T075949_N0205_R035_T36NWH_20171007T081821.SAFE already processed
# imagery/l1c/S2B_MSIL1C_20171007T075949_N0205_R035_T36NWJ_20171007T081821.SAFE already processed
# imagery/l1c/S2B_MSIL1C_20171007T075949_N0205_R035_T36NWK_20171007T081821.SAFE already processed
# imagery/l1c/S2B_MSIL1C_20171007T075949_N0205_R035_T36NXH_20171007T081821.SAFE already processed
# imagery/l1c/S2A_MSIL1C_20170823T075611_N0205_R035_T36NWK_20170823T080952.SAFE already processed
# imagery/l1c/S2A_MSIL1C_20170823T075611_N0205_R035_T36NXG_20170823T080952.SAFE already processed
# imagery/l1c/S2A_MSIL1C_20170823T075611_N0205_R035_T36NXH_20170823T080952.SAFE already processed
# imagery/l1c/S2A_MSIL1C_20170823T075611_N0205_R035_T36NXJ_20170823T080952.SAFE already processed
# imagery/l1c/S2A_MSIL1C_20170823T075611_N0205_R035_T36NWJ_20170823T080952.SAFE already processed
# imagery/l1c/S2B_MSIL1C_20170907T075559_N0205_R035_T36NWJ_20200712T174851.SAFE already processed
# imagery/l1c/S2A_MSIL1C_20171002T075741_N0205_R035_T36NXH_20171002T081741.SAFE already processed
# imagery/l1c/S2A_MSIL1C_20171002T075741_N0205_R035_T36NXJ_20171002T081741.SAFE already processed
# imagery/l1c/S2A_MSIL1C_20171002T075741_N0205_R035_T36NXK_20171002T081741.SAFE already processed
# imagery/l1c/S2B_MSIL1C_20170815T074609_N0205_R135_T36NXH_20200712T233135.SAFE already processed
# imagery/l1c/S2B_MSIL1C_20170815T074609_N0205_R135_T36NYH_20200713T005439.SAFE already processed
# imagery/l1c/S2B_MSIL1C_20170818T075609_N0205_R035_T36NXH_20200713T020554.SAFE already processed
# imagery/l1c/S2B_MSIL1C_20170818T075609_N0205_R035_T36NXJ_20200713T025610.SAFE already processed
# imagery/l1c/S2B_MSIL1C_20170907T075559_N0205_R035_T36NWH_20200712T182100.SAFE already processed
# imagery/l1c/S2B_MSIL1C_20170927T075649_N0205_R035_T36NWJ_20200710T030535.SAFE already processed
# imagery/l1c/S2B_MSIL1C_20170927T075649_N0205_R035_T36NXH_20200707T172257.SAFE already processed
# imagery/l1c/S2B_MSIL1C_20170927T075649_N0205_R035_T36NXJ_20200708T224603.SAFE already processed
# imagery/l1c/S2B_MSIL1C_20170927T075649_N0205_R035_T36NXK_20200710T165446.SAFE already processed
# imagery/l1c/S2B_MSIL1C_20171004T074919_N0205_R135_T36NXG_20171004T080547.SAFE already processed
# imagery/l1c/S2B_MSIL1C_20170907T075559_N0205_R035_T36NXH_20200708T062537.SAFE already processed
# imagery/l1c/S2B_MSIL1C_20170907T075559_N0205_R035_T36NXJ_20200711T180609.SAFE already processed
# imagery/l1c/S2B_MSIL1C_20170907T075559_N0205_R035_T36NXK_20200712T055330.SAFE already processed
# imagery/l1c/S2B_MSIL1C_20170927T075649_N0205_R035_T36NWH_20200711T055140.SAFE already processed

# %% [markdown]
# ## Create a mosaic

# %% [markdown]
# We will next create a mosaic from the surface reflectance data that spans the entire sample. Since imagery from a single day does not cover the entire sample, we will need to combine images from multiple dates.
#
# There are several programs to create sophisticated composites, such as [Sen2Three](http://step.esa.int/main/third-party-plugins-2/sen2three/) and [Sen2Mosaic](https://sen2mosaic.readthedocs.io/en/latest/). These have functionality to create composites containing only clear pixels, and they can be very useful for classification tasks when image clarity is essential and treating pixels from different dates as part of the same image is valid. However, these programs often have dependency issues, and sometimes fail on products produced from different versions of Sen2Cor.
#
# Since we only aim to plot an image for data exploration, and since all of the images we downloaded have reasonably low cloud cover, we will instead just plot images from 2 arbitrary dates. Examining the date coverage metrics from the API results, it seems likely that using imagery from 2017-09-07 and 2017-09-09 will cover the entire sample, and this is very close to the time when the crop cuts were collected. We will try using the images from these dates to construct the mosaic.

# %% [markdown]
# ### True-color composite

# %% [markdown]
# We will begin with a true color composite. L2A Sentinel-2 data produced using `sen2cor` includes a true-color composite that includes excellent color clarity. We will use these images from each image and stitch them into a larger raster that covers the full sample.

# %%
from osgeo import gdal

tiles = []
for x in glob.glob(l2a_directory + '/*MSIL2A_20170907*.SAFE/GRANULE/L2A*/IMG_DATA/R10m/*TCI*.jp2'):
    tiles.append(x)
for x in glob.glob(l2a_directory + '/*MSIL2A_20170909*.SAFE/GRANULE/L2A*/IMG_DATA/R10m/*TCI*.jp2'):
    tiles.append(x)
    
vrt = gdal.BuildVRT(os.getcwd() + '/imagery/composites/true_color.virt', tiles, srcNodata=0,VRTNodata=0)
vrt.FlushCache()

# %% [markdown]
# ### False-color composite

# %% [markdown]
# Second, we will create a false color composite to make vegetation more easily visible. We will assign the NIR band to red, red to green, and green to blue. This product is not present in the L2A data product, so we will need to create it for each tile before generating the image.
#
# To create the composite, we will use the python package `raterio`. This provides wrappers for GDAL which make it easier to load rasters into arrays, manipulate the data, and then generate output rasters.
#
# The raw bands are stored as unsigned 16 bit integers. However, for display purposes we will want 8 bit unsigned integers. Without manipulating the image at all, the output will essentially just be a red image. To create a more effective output, we use three packages from the scikit-image exposure package. First, we use `exposure.adjust_log` to adjust contrast in the image. This is particularly useful since cloud cover creates outliers in all three bands. Second, `exposure.equalize_adapthist` is used for local histogram equalization which improves contrast in the image and helps equalize contrast globally. Finally, a gamma adjustment is applied to brighten dark areas of each band and reduce color imbalance (identified because the clouds appeared slightly red).
#
# After each of the tiles is created, they are merged into a single (virtual) mosaic using the same method as the true color image.

# %%
import rasterio 
import numpy as np
from skimage.transform import resize
from skimage import exposure


def normalize_8bit(b3, b4, b8):
    b3 = exposure.adjust_gamma(exposure.equalize_adapthist(exposure.adjust_log(b3, 1)), .75)
    b4 = exposure.adjust_gamma(exposure.equalize_adapthist(exposure.adjust_log(b4, 1)), .75)
    b8 = exposure.adjust_gamma(exposure.equalize_adapthist(exposure.adjust_log(b8, 1)), .85)
    _min = min(np.min(b3), np.min(b4), np.min(b8))
    _max = min(np.max(b3), np.max(b4), np.max(b8))
    b3 = np.array((b3 - _min) * ((255 - 0) / (_max - _min)) + 0, dtype=np.uint8)
    b4 = np.array((b4 - _min) * ((255 - 0) / (_max - _min)) + 0, dtype=np.uint8)
    b8 = np.array((b8 - _min) * ((255 - 0) / (_max - _min)) + 0, dtype=np.uint8)
    return b3, b4, b8


def false_color(product, saveDir):
    if os.path.exists(saveDir +'/' + os.path.splitext(os.path.basename(product))[0] + '_false_color.jp2'):
        return  # Avoid re-processing images 

    bandPath = product + '/GRANULE/L*/IMG_DATA/R10m/'

    tci_path = bandPath+'*TCI*.jp2'
    for x in glob.glob(tci_path):
        tci_path = x

    b8_path = bandPath+'*B08*.jp2'
    for x in glob.glob(b8_path):
        b8_path = x
    with rasterio.open(b8_path) as f:
        b8 = f.read(1)

    b3_path = bandPath+'*B03*.jp2'
    for x in glob.glob(b3_path):
        b3_path = x
    with rasterio.open(b3_path) as f:
        b3 = f.read(1)

    b4_path = bandPath+'*B04*.jp2'
    for x in glob.glob(b4_path):
        b4_path = x
    with rasterio.open(b4_path) as f:
        b4 = f.read(1)

    mask = (b8==0)  # Indicates where data should be set to 0
    b3, b4, b8 = normalize_8bit(b3, b4, b8)
    for b in [b3, b4, b8]:
        b[mask] = 0

    # Set spatial characteristics of the output object to TCI
    with rasterio.open(tci_path) as src:
        kwargs = src.meta

    with rasterio.open(saveDir +'/' + os.path.splitext(os.path.basename(product))[0] + '_false_color.jp2', 
                       'w', **kwargs) as dst:
        dst.write_band(3, b3)
        dst.write_band(2, b4)
        dst.write_band(1, b8)
        
        
for x in glob.glob(l2a_directory + '/*MSIL2A_20170907*.SAFE'):
    false_color(x, os.getcwd() + '/imagery/composites/fc-tiles')
for x in glob.glob(l2a_directory + '/*MSIL2A_20170909*.SAFE'):
    false_color(x, os.getcwd() + '/imagery/composites/fc-tiles')

    
tiles = []
for x in glob.glob(os.getcwd() + '/imagery/composites/fc-tiles/*.jp2'):
    tiles.append(x)
    
vrt = gdal.BuildVRT(os.getcwd() + '/imagery/composites/false_color.virt', tiles, srcNodata=0,VRTNodata=0)
vrt.FlushCache()

# %% [markdown]
# ## Plot the rasters

# %% [markdown]
# Folium supports plotting rasters. However, it dose not handle large rasters well and will crash if we try to plot these images. The images are similarly too large to display on most computers with matplotlib. It is possible to plot in Python, but it is easier and more informative to load the image in GIS software such as QGIS or ArcGIS. Hence, we will not plot it here.
#
# In the second notebook in the tutorial, we will use the processed Sentinel-2 imagery to calculate vegetation indices and zonal statistics.
